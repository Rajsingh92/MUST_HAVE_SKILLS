# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
fig,ax = plt.subplots()


x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':')  # dotted

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r')  # dotted red

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
#[xmin, xmax, ymin, ymax]
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# [-1, 11, -1.5, 1.5]

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend()

# %% [markdown]
# # Multiple Subplots

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig,ax =  plt.subplots(2,2)
x = np.arange(1,5)

ax[0][0].plot(x,x*x)
ax[0][0].set_title('square')

ax[0][1].plot(x,np.sqrt(x))
ax[0][1].set_title('square root')

ax[1][0].plot(x,np.exp(x))
ax[1][0].set_title('exp')

ax[1][1].plot(x,np.log10(x))
ax[1][1].set_title('log')

plt.show()

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# # Customizing Legends

# %%
plt.style.use('classic')

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend()

# %%
ax.legend(loc='upper left', frameon=False)

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# # Distribution plots

# %%
df = pd.read_csv('schoolimprovement2010grants.csv')
df.head()
# Out:
#    Unnamed: 0                        School Name      City State  \
# 0           0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1           1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2           2                     GAMBELL SCHOOL   GAMBELL    AK
# 3           3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4           4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name  Model Selected  Award_Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                     YUPIIT SCHOOL DISTRICT  Transformation        520579
# 2              BERING STRAIT SCHOOL DISTRICT  Transformation        449592
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation        641184
# 4                     YUPIIT SCHOOL DISTRICT  Transformation        399686
#
#   Region
# 0   West
# 1   West
# 2   West
# 3   West
# 4   West

# %%
df['Award_Amount'].plot.hist()

# %%
sns.distplot(df['Award_Amount'])

# %%
sns.distplot(df['Award_Amount'],color='red')

# %%
sns.distplot(df['Award_Amount'],color='red',vertical=True)

# %%
sns.distplot(df['Award_Amount'],color='red',hist=False)

# %%
sns.distplot(df['Award_Amount'],color='red',hist=False,rug=True)

# %%
sns.distplot(df['Award_Amount'],kde=False,bins=20)

# %%
sns.distplot(df['Award_Amount'],hist=True,rug=True,kde_kws={'shade':True})

# %% [markdown]
# # Regression plots

# %%
df = pd.read_csv('insurance_premiums.csv')
df.head()
# Out:
#         State  fatal_collisions  fatal_collisions_speeding  \
# 0     Alabama              18.8                         39
# 1      Alaska              18.1                         41
# 2     Arizona              18.6                         35
# 3    Arkansas              22.4                         18
# 4  California              12.0                         35
#
#    fatal_collisions_alc  fatal_collisions_not_distracted  \
# 0                    30                               96
# 1                    25                               90
# 2                    28                               84
# 3                    26                               94
# 4                    28                               91
#
#    fatal_collisions_no_hist  premiums  insurance_losses Region
# 0                        80    784.55            145.08  South
# 1                        94   1053.48            133.93   West
# 2                        96    899.47            110.35   West
# ...

# %%
sns.regplot(data=df,x="insurance_losses",y="premiums")

# %%
sns.regplot(data=df,x="insurance_losses",y="premiums",color='g')

# %%
sns.lmplot(data=df,x="insurance_losses",y="premiums")

# %%
sns.lmplot(data=df,x="insurance_losses",y="premiums",hue="Region")

# %%
sns.lmplot(data=df,x="insurance_losses",y="premiums",hue="Region", markers=["o", "v","1","+"], palette="Set1")

# %%
sns.lmplot(data=df,x="insurance_losses",y="premiums",row="Region")

# %%
sns.lmplot(data=df,x="insurance_losses",y="premiums",col="Region")

# %% [markdown]
# # Categorical plots

# %%
df = pd.read_csv('schoolimprovement2010grants.csv')
df.head()
# Out:
#    Unnamed: 0                        School Name      City State  \
# 0           0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1           1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2           2                     GAMBELL SCHOOL   GAMBELL    AK
# 3           3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4           4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name  Model Selected  Award_Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                     YUPIIT SCHOOL DISTRICT  Transformation        520579
# 2              BERING STRAIT SCHOOL DISTRICT  Transformation        449592
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation        641184
# 4                     YUPIIT SCHOOL DISTRICT  Transformation        399686
#
#   Region
# 0   West
# 1   West
# 2   West
# 3   West
# 4   West

# %%
sns.stripplot(data=df,y='Award_Amount',x='Model Selected')

# %%
sns.stripplot(data=df,x='Award_Amount',y='Model Selected',jitter=True)

# %%
sns.stripplot(data=df,x='Award_Amount',y='Model Selected',hue='Region')

# %%
sns.stripplot(data=df,y='Award_Amount',x='Model Selected',hue='Region', jitter=True, palette="icefire", size= 7, dodge=True, lw=0.5)

# %%
sns.boxplot(data=df,y='Award_Amount',x='Model Selected')

# %%
sns.boxplot(data=df,y='Award_Amount',x='Model Selected',hue='Region')

# %%
sns.boxplot(data=df,y='Award_Amount',x='Model Selected',hue='Region',palette="hsv")

# %%
sns.factorplot(data=df,y='Award_Amount',x='Model Selected',col='Region',palette="hsv",kind="box")

# %%
sns.boxplot(data=df,y='Award_Amount',x='Model Selected')
sns.stripplot(data=df,y='Award_Amount',x='Model Selected')

# %%
sns.boxplot(data=df,y='Award_Amount',x='Model Selected')
sns.swarmplot(data=df,y='Award_Amount',x='Model Selected')

# %%
 sns.swarmplot(data=df,y='Award_Amount',x='Model Selected',palette="viridis")

# %%
fig, ax = plt.subplots(figsize=(10,20))
sns.violinplot(data=df,ax = ax,x='Award_Amount',y='Model Selected',palette='husl')

# %%
fig, ax = plt.subplots(figsize=(10,20))
sns.violinplot(data=df,ax = ax,x='Award_Amount',y='Model Selected',palette="rocket", split=True)

# %%
# Loading Built-in Dataset:
tips = sns.load_dataset("tips")

# Plotting a simple Jointplot:
sns.pairplot(data=tips, hue="sex", palette="icefire", x_vars=["total_bill", "size"], y_vars=["tip"], size=6, aspect=.85, kind="reg")

# %%
iris = sns.load_dataset("iris")
# iris.columns
sns.set(style="dark")

sns.pairplot(iris, hue="species", palette="gist_heat", dropna=True)

# %%
sns.pairplot(iris, hue="species", palette="rocket", diag_kind="kde", size=4)

# %%
# Loading Built-in Dataset:
tips = sns.load_dataset("tips")

# Plotting a simple Jointplot:
sns.jointplot(x="total_bill", y="tip", data=tips)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

# %%
# Loading Iris dataset:
iris = sns.load_dataset("iris")

# Replace the scatterplots and histograms with density estimates and align the marginal Axes tightly with joint Axes:
sns.jointplot("sepal_width", "petal_length", data=iris, kind="kde", space=0.2)

# %%
 from matplotlib.axes._axes import _log as matplotlib_axes_logger
 matplotlib_axes_logger.setLevel('ERROR')

# %%
fig, ax = plt.subplots(figsize=(10,20))

sns.boxenplot(data=df,ax=ax,x='Award_Amount',y='Model Selected',palette='Paired',hue='Region')

# %%
sns.countplot(data=df,x="Model Selected",hue="Region")

# %%
sns.pointplot(data=df,y='Award_Amount',x='Model Selected',capsize=.1)

# %%
sns.barplot(data=df,y='Award_Amount',x='Model Selected')

# %%
sns.barplot(data=df,y='Award_Amount',x='Model Selected',hue='Region')

# %%
df = pd.read_csv('college_datav3.csv')
df.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %%
sns.regplot(data=df,y='Tuition',x="SAT_AVG_ALL",marker='^',color='g')

# %%
sns.regplot(data=df,y='Tuition',x="REGION")

# %%
sns.regplot(data=df,y='Tuition',x="REGION",x_estimator=np.mean)

# %%
sns.regplot(data=df,y='Tuition',x="REGION",x_estimator=np.mean,order=3)

# %%
sns.regplot(data=df,y='Tuition',x="UG",fit_reg=False)

# %%
sns.regplot(data=df,y='Tuition',x="UG",fit_reg=True)

# %%
sns.regplot(data=df,y='Tuition',x="UG",x_bins=5)

# %%
sns.regplot(data=df,y='Tuition',x="UG",x_bins=8)

# %%
# Display the residual plot
sns.residplot(data=df,
          y='Tuition',
          x="SAT_AVG_ALL",
          color='g')

# %% [markdown]
# ## Pandas - Visualization

# %%
import pandas as pd
import seaborn as sns; 
import warnings
warnings.filterwarnings(action='ignore')

# %%
iris = sns.load_dataset("iris")

# %%
iris = iris[1:6]
iris
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
iris.plot()

# %%
iris.plot.bar()

# %%
iris.plot.bar(stacked=True)

# %%
iris.plot.barh(stacked=True)

# %%
iris.plot.hist(bins=15)

# %%
iris.plot.hist(stacked=True, bins=15)

# %%
iris.plot.box()

# %%
iris.plot.area()

# %%
ax=iris.plot.scatter(x='sepal_length', y='sepal_width',color='DarkGreen', label='Group 1')
iris.plot.scatter(x='petal_length', y='petal_width', color='DarkBlue', label='Group 2', ax=ax)
